# %% [markdown]
# # Beam design interactive model

# %%
# %matplotlib widget

from bmcs_cross_section.cs_design.cs_design import CSDesign, Info
from bmcs_cross_section.cs_design import CrossSectionLayout
from bmcs_cross_section.mkappa.mkappa import MKappa
import bmcs_utils.api as bu
from bmcs_cross_section.cs_design.cs_shape import CrossSectionShapeBase, RectangleCS, CircleCS, TShapeCS

mc = MKappa()

cs = CSDesign(H=200)
csl = mc.cross_section_layout
css = RectangleCS()
bu.InteractiveWindow([cs,csl,css]).interact()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c3baac1d1d1b> in <module>
#       7 from bmcs_cross_section.cs_design.cs_shape import CrossSectionShapeBase, RectangleCS, CircleCS, TShapeCS
#       8
# ----> 9 mc = MKappa()
#      10
#      11 cs = CSDesign(H=200)
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in _init_trait_listeners(self)
#    3204         """
#    3205         for name, data in self.__class__.__listener_traits__.items():
# -> 3206             getattr(self, "_init_trait_%s_listener" % data[0])(name, *data)
#    3207
#    3208     def _init_trait_method_listener(self, name, kind, config):
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in _init_trait_delegate_listener(self, name, kind, pattern)
#    3271             )
#    3272
# -> 3273         self.on_trait_change(notify, name_pattern, target=self)
#    3274         self.__dict__.setdefault(ListenerTraits, {})[name] = notify
#    3275
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in on_trait_change(self, handler, name, remove, dispatch, priority, deferred, target)
#    2550                     deferred=deferred,
#    2551                 )
# -> 2552                 listener.register(self)
#    2553
#    2554     # A synonym for 'on_trait_change'
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\traits_listener.py in register(self, new)
#     384             # Set up the appropriate trait listeners on the object for the
#     385             # current trait:
# --> 386             value = getattr(self, type)(new, name, False)
#     387
#     388         if len(traits) == 1:
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\traits_listener.py in _register_simple(self, object, name, remove)
#     605             # 'trait_b' will have been initialized already, and the
#     606             # registration that we are deferring will never happen.
# --> 607             return next.register(getattr(object, name))
#     608
#     609         return (object, name)
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\trait_types.py in create_default_value(self, *args, **kw)
#    3362                 raise TraitError("Unable to locate class: " + args[0])
#    3363
# -> 3364         return klass(*args[1:], **kw)
#    3365
#    3366     #: fixme: Do we still need this method using the new style?...
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in _init_trait_listeners(self)
#    3204         """
#    3205         for name, data in self.__class__.__listener_traits__.items():
# -> 3206             getattr(self, "_init_trait_%s_listener" % data[0])(name, *data)
#    3207
#    3208     def _init_trait_method_listener(self, name, kind, config):
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in _init_trait_delegate_listener(self, name, kind, pattern)
#    3271             )
#    3272
# -> 3273         self.on_trait_change(notify, name_pattern, target=self)
#    3274         self.__dict__.setdefault(ListenerTraits, {})[name] = notify
#    3275
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py in on_trait_change(self, handler, name, remove, dispatch, priority, deferred, target)
#    2550                     deferred=deferred,
#    2551                 )
# -> 2552                 listener.register(self)
#    2553
#    2554     # A synonym for 'on_trait_change'
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\traits_listener.py in register(self, new)
#     384             # Set up the appropriate trait listeners on the object for the
#     385             # current trait:
# --> 386             value = getattr(self, type)(new, name, False)
#     387
#     388         if len(traits) == 1:
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\traits_listener.py in _register_simple(self, object, name, remove)
#     605             # 'trait_b' will have been initialized already, and the
#     606             # registration that we are deferring will never happen.
# --> 607             return next.register(getattr(object, name))
#     608
#     609         return (object, name)
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\trait_types.py in create_default_value(self, *args, **kw)
#    3362                 raise TraitError("Unable to locate class: " + args[0])
#    3363
# -> 3364         return klass(*args[1:], **kw)
#    3365
#    3366     #: fixme: Do we still need this method using the new style?...
#
# ~\miniconda3\envs\bmcs_env\lib\site-packages\traits\util\deprecated.py in wrapper(*args, **kw)
#      29
#      30             warnings.warn(message, DeprecationWarning, stacklevel=2)
# ---> 31             return fn(*args, **kw)
#      32
#      33         return wrapper
#
# TypeError: __call__() missing 1 required positional argument: 'adaptee'
